# %% [markdown]
# # Stack Plot Example 1 Using Random Numbers

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create some random data to plot

# %%
x = range(1,21)
y1 = np.random.rand(20)
y2 = np.random.rand(20)

# print values to see what we have
print(x)
print(y1)
print(y2)
# Out:
# range(1, 21)
# [0.0602451  0.84359275 0.26909518 0.9337283  0.52681594 0.71490835
#  0.92443468 0.29106676 0.06345538 0.0171715  0.00199148 0.15570312
#  0.72402548 0.14135963 0.61527827 0.99035578 0.54235607 0.52689411
#  0.15966288 0.30036565]
# [0.51617723 0.83317042 0.21643021 0.10765298 0.51861984 0.02938304
#  0.45472456 0.94805591 0.02418983 0.9705699  0.08000183 0.21813048
#  0.01642223 0.18948081 0.91787017 0.10428675 0.85746903 0.30518675
#  0.6254811  0.4468375 ]

# %%
# setup legend for plot
plt.plot([], [], color='r', label='y1')
plt.plot([], [], color='b', label='y2')

# setup the plot
plt.stackplot(x, y1, y2, colors=['r', 'b'])
plt.title('Stack Plot Random Numbers')
plt.legend()
plt.show()
